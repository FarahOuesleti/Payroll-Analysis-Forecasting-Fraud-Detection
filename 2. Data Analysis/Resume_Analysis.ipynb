# %% [markdown]
# # 1. Timesheet

# %% [markdown]
# ## a. MCA

# %% [markdown]
# ### i. Axis Contribution :

# %% [markdown]
# - col1_AJ has maximum contribution to the 1st Dimension
# - col1_TR has maximum contribution to the 2nd Dimension
# - col3_ER has maximum contribution to the 3rd Dimension
# - col3_RN has maximum contribution to the 4th Dimension

# %% [markdown]
# ### ii. Graphs Interpretation :

# %% [markdown]
# ![image.png](attachment:fe4a72b6-6f09-4c30-8ce2-d720a165d74f.png)

# %% [markdown]
# ______________________________________________
# __________________________________________________
# - MOTIF2 : **PC & RN** are closest to MOTIF3 : **TR**
# - MOTIF3 : **RN** is closest to MOTIF4 **EM**
# - MOTIF2 ER & FR are supersposed
# - MOTIF1 **RN** & MOTIF3 **EM** are superposed
# - MOTIF1 **HC** & MOTIF1 **ER** are superposed
# - MOTIF2 **AK** & MOTIF2 **AF** are closest to eachother, and closest to MOTIF1 **AJ**
# - MOTIF3 **AK & AC** are closest to eachother
# __________________________________________________
# -  CODABS **CSS** & CODABS **ABS** are closest to eachother, as well as to **ATR** & MOTIF4 **ER**
# - CODABS **MAT** is closest to MOTIF4 TR & MOTIF1 **AK**
# __________________________________________________
# __________________________________________________
# - **CODABS CSO** is closest to MOTIF1 : AS , MOTIF2 : Ac , MOTIF1 : AF , MOTIF3 : AS & SOURCE : **R**
# - **CODABS : CSS** is closest to MOTIF4 : TR & ER, MOTIF3 : AK , **CODABS : MAN** and MOTIF2 : AK
# - **CODABS : ABS & MAB** are superposed and are closest to col1_AH
# - **CODABS : CPN** is closest to col0_MT202211, AND they are alose closest to : SOURCE : **R**, **CODABS : ATR** , MOTIF1 : AC

# %% [markdown]
# ________________________________________________________
#                                 -------------- After Omitting the MOTIFs columns -----------------------------
# _____________________________________________________________

# %% [markdown]
# ![image.png](attachment:5d1a8e43-0910-4480-851a-eb02ae4f35ec.png)

# %% [markdown]
# ![image.png](attachment:1e5bc605-895c-462e-8da6-3b2078113501.png)

# %% [markdown]
# ![image.png](attachment:7ed6c969-2d12-4996-bfa0-cc544087987a.png)

# %% [markdown]
# - **MAB & MAT** **(Maternity Leave (paid & unpaid))** Absence Reasons tend to be **29days** long.
# - **999** Entry/Leave Absence reasons tend to take **17 to 22 days**
# - **Unjustified Leave** & **Unpaid Sick Leave** tend to vary from **6 to 9days**
# - **CSO : Social Leave** tends to be **1 to 3 days long**
# - **CPN : Paid Leave** tends to be **4 to 5days**
# ________________________________
# - **Source : R** tends to be used on CPN & CSO
# - **Source : std(no recall)** tneds to be more frequent for **MAT & MAB**

# %% [markdown]
# ## b. PCA

# %% [markdown]
# ### i. Correlation Matrix

# %% [markdown]
# ![image.png](attachment:c2b4e911-29f2-4e15-bd51-1cd7b22967a1.png)

# %% [markdown]
# DATEDEB - DATFIN - DEBACQ - FINACQ - ANNEE_REF : These values present correaltion = 1. One variable should be enough to represent their correlations to the other features.
#
# We'll only keep DATDEB and discard DATFIN - DEBACQ - FINACQ - ANNEE_REF from the correlation Matrix.

# %% [markdown]
# Refined Correlation matrix :
#
# ![image.png](attachment:c1ad672f-abee-430a-ae3a-9048905d0c4e.png)

# %% [markdown]
# Negatively correlated with DATDEB :
# - Medium++ : REP_AN_SUIV
# - Weak+ : REP_AN_PREC
#
# Negatively correlated with DATEDEB & DTUPD1 :
# - Medium++ : DR_PRI
# - Medium+ : DR_ACQ
#
# Negatively correlated with DR_REST :
# - Highly : DR_PRI
# - Medium : REP_AN_SUIV
# - Weak : DR_ACQ
# - Weak- : REP_AN_PREC
#
#
# Positively correlated :
# - Very Highly +++ : CONSOM_DUR_int & ACQ_DUR_int
# - Highly++ : DR_REST & DATEDEB
# - Medium : DR_PRI & DR_ACQ

# %% [markdown]
# To_KEEP = DEBABS, DATDEB, DR_REST, DR_PRI, DR_ACQ, REP_AN_SUIV, ABS_DUR_int, ACQ_DUR_int

# %% [markdown]
# ### ii. Scree Plot

# %% [markdown]
# ==> 2 values are enough to represent 80% of the information

# %% [markdown]
# ### iii. Correlation circle

# %% [markdown]
# ![image.png](attachment:a0f2584e-03d6-435e-80aa-0ec620ae7888.png)

# %% [markdown]
# - ABS_DUR_int & DR_REST are independant
# - CODABS_enc & ABS_DUR_int are highly positively correlated
# - DR_REST & REP_AN_SUIV are slightly correlated
# - DR_ECR & DR_PAY are around 0 for both axis, therefore they will be discarded, their significance is negligebale.

# %% [markdown]
# ### iv. Scatter Plot

# %% [markdown]
# ![image.png](attachment:27061714-90e5-4929-a6a5-244bf9bc0bfa.png)
# ![image.png](attachment:db395fd7-094b-4a2c-80e8-44315fec08ba.png)
# ![image.png](attachment:d0c3082c-0ab5-4691-a656-c887e3e71bde.png)

# %% [markdown]
# Linear relationship between :
# - DR_REST & REP_AN_PREC
# - REP_AN_SUIV & REP_AN_PREC
# - DR_REST & AJUST4 (for positive values of AJUST4), small pente
#
# Polynomial (X**3) :
# -  AJUST4 & REP_AN_SUIV

# %% [markdown]
# -----------------------------
# -----------------------------

# %% [markdown]
# # 2. MisClassification

# %% [markdown]
# ## a. MCA

# %% [markdown]
# ### i. Axis Contribution :

# %% [markdown]
# - **Leave_Reason** : col6_TRANSF has maximum contribution to the 1st Dimension
# - **NATCONT** & **TYPCONT** col2_TS & col1_ST have maximum contribution to the 2nd Dimension
#
# ----------- POSTs ADDED -----------
#
# - **CODSOR** : Mutation has maximum contribution to the 1st Dimension
# - **Leave_Reason** : TRANSF has maximum contribution to the 2nd Dimension

# %% [markdown]
# ### ii. Graphs Interpretation :

# %% [markdown]
# ![image.png](attachment:f957df49-b70e-427c-a1ed-510910056c3a.png)

# %% [markdown]
# _______________________
#
# - Leave_Category : **ENDCTR** is closest to **DD & ST** : Contract Type / Nature
# - DD & TI are superposed
# - ST & TS are superposed
#
# - Leave_Reason : **FINCTR** is closest to **ORGANI** & **mutation**
# - Transfer_Reason : **ORGANI** (internal organisation) &  CODSOR : **mutation** are superposed
#
# - Current_Company : **ITI** is closest to CODSOR : **Left** , Leave_Category : **DEM** & **CurrentlyIN**
#
# - Leave_Category : **MOFOF** (Leaving company for competition) is closest to CODENT : **Rerecruited** & **Mutation**
#
# - Current_Company : **AFA** is closest to Leave_Reason & Leave_Category : **TRA & TRANSFER**
#
# - NATCON : **TR** is closest to Current_Company : **EXM** & **AFA**
#
# __________________________________________________________________________________________________________
# ______________________________________________________________________
#
# - Current_Company : **ITM** is closest to col2_T3 & T2 as well as TYPCON : **AN**
# - Current_Company : **SMS** is close to Current_Company :**ITM**
# - Current_Company **TWW** is CLOSEST to TYPCON : **DI**
# - Current_Company **TMG** is close to Current_Company **TWW**
#
# - Leave_Reason : **FPEF**(FPE Formation) is closest (almost superposed) to Leave_Category : **RPU & LIC**
# - Leave_Reason : **FPEP**(FPE Production) is SUPERPOSED to Leave_Category : **INVOL**
# - Leave_Reason : **RAIPR**, **MOFNO**, **ABN**, **NSF**, **AUTRE**, **RE** **ET**, & most of other col7 values are superposed.
#
# - VOLUNT & STANDARD are superposed
# - Current_Company : **IMI** is closest to **VOLUNT-STANDARD**, Leave_Category : **DECEAS**, Leave_Reason : **DEPET** ,, by far to Leave_Reason : **DEM, REMUN, DESIST**
#
# ___________________________________________________________________________________

# %% [markdown]
# ![image.png](attachment:5fe6f9ed-87d8-44b7-b13d-aaa447092807.png)

# %% [markdown]
# - QUALIT : **Mr** is closest to ENTRY_CATEGORY : **ACTIVE** & CODENT : **new recruit**

# %% [markdown]
# ![image.png](attachment:58d7dc49-d263-409c-a473-3b1e1c6811eb.png)

# %% [markdown]
# - QUALIT : **Miss** , Leave_Category : **AUTRE1** & Current_Company : **ATX** are very close to eachother

# %% [markdown]
# _________________________________________________________
#                                      -------------- POSTS ADDED RELATED -----------------
# _________________________________________________________

# %% [markdown]
# ![image.png](attachment:32f6e78b-8fd0-4910-904a-6cefe9d6a89c.png)

# %% [markdown]
# ![image.png](attachment:74b9a472-9526-4946-a22b-a4a015d01a30.png)
# ![image.png](attachment:61a87fdc-1d83-4840-8c40-49c0f9214b85.png)
# ![image.png](attachment:1ba05112-345f-4ad3-bd59-e1f670ef9ada.png)

# %% [markdown]
# ![image.png](attachment:c8e459b8-faf4-483e-ad19-52d282d5194b.png)

# %% [markdown]
# ![image.png](attachment:d16fcd96-1755-429e-b646-f53d38c5bc72.png)

# %% [markdown]
# - **TITLE** : Supervisor (AMA) is closest to **Transfer Reason** : Carrier Change & **Transfer Company** : TW2, SMS, and a bit farther : ITM, IMI
# - **TITLE** : Executive C2, Supervisor / CAD are closest to  Mutation
# _______________________________
# - **TITLE** : Executive C3 is closest to  **LIBELLE TRAVAIL** : Part Time (relatively to axis mutation)
# - **TITLE** : Employee E1, Employee In Interation Phase are closest to **Original Company** : SMS
# - **TITLE** : Employee E4 , Assimilated Executive and Supervisor are almost superposed.
# - **TITLE** : EMP & EMI, **Specific Title** : Employee E1, Employee E3, Executive C1, are closest to **LIBELLE TRAVAIL** : Full Time

# %% [markdown]
# ## b. PCA

# %% [markdown]
# ### i. Correlation Matrix

# %% [markdown]
# ![image.png](attachment:b760993a-63a0-4cdd-aeb9-7d1f6372923a.png)

# %% [markdown]
# _______________________________________
# _______________________________________
#                                                             MOST INTRESTING :
# _______________________________________
# _______________________________________
# Negatively correlated with SEN_DUR_1_int :
# - Highly : SEN_DUR_2_int
# - Medium : CODENT_enc
# - Medium : SEN_GRP_DUR_int
# - Highly : DATAN4
#
# Positively :
# - Medium : DATCON
# ____________________________________
# Positively correlated with DATCON :
# - **VERY Highly+** : **DEBESS, DATAN1, DATENT**
# - **Medium+ : DATSOR,DATFIN,SEN_DUR_1_int**
# ___________________________________________
#   Positively correlated with DEBESS :
# - **VERY Highly+** : DATENT, DATAN1
# - **Highly** : -2-3
# - Medium+ : DATSOR, DATFIN
# ___________________________________________
# Negatively correlated with FINESS :
# - Medium+ : PHYSOR
#
# ___________________________________________
# Negatively correlated with ESSS_DUR_int :
# - Medium+ : PHYSOR
#
# Positively correlated with ESSS_DUR_int :
# - **Highly : FINESS**
# __________________________________________________________________
# Negatively correlated with DATAN4 :
# - **Highly : SEN_DUR_1_int**
#
# Positively correlated with DATAN4 :
# - **High : DTCY01**
# - Medium- : DTCY02
# - Medium-- : CODSOR_enc, SEN_DUR_2_int
# _______________________________________
# Negatively correlated with DATSOR :
# - Medium : CODSOR_enc
#
# Positively correlated with DATSOR :
# - Medium+ : SEN_GRP_DUR_int
# _______________________________________
# Negatively correlated with DATENT :
# - Medium : SEN_GRP_DUR_int
# - Very lightly : Qualit_enc (Minority class entries)
#
# Positively correlated with DATENT
# - **Very Highly : DATSOR,DATAN1,DATCON**
# - Highly+ : DEBESS, DATFIN
# - NUDOSS : Means that more Entry Dates in recent years correspond to higher values for NUDOSS (which totally natural) - Discard, irrelevant
# - light : SEN_DUR_1_int

# %% [markdown]
# _______________________________________
# _______________________________________
#                                                             PROBABLY INTRESTING :
# _______________________________________
# _______________________________________
#
# Negatively correlated with DTCY01 :
# - Highly : SEN_DUR_1_int (<-0.6)
#
# Positively correlated with DTCY01 :
# - Highly+ : SEN_DUR_2_int (>0.8)
# - Highly : DATAN4
# - Medium : DTCY02
# - lighter- : CODSOR_enc
# ____________________________________
#
# Positively correlated with DATFIN :
# - HIGH : DATSOR DATENT DATCON
# - Medium++ :  DEBESS, DATAN1, CODSOR_enc, CONT_GRP_DUR_int

# %% [markdown]
# _______________________________________
# _______________________________________
#                                                             OTHER :
# _______________________________________
# _______________________________________
#
# Positively correlated with SEN_GRP_DUR_int :
# - Medium+ : CODSOR_enc
# - Medium : DATFIN
# - HIGH : CONT_GRP_DUR_int
# ____________________________________
# Negatively correlated with SEN_GRP_DUR_int :
# - Medium : DATSOR
# ____________________________________
# Negatively correlated with DATFIN :
# - Medium+ : SEN_GRP_DUR_int
#
# Positively correlated with DATFIN :
# - highly+ : DATSOR,DATCON,
# - High : DATENT, DEBESS, DATAN1
# - Medium : CODSOR_enc, CONT_GRP_DUR_int,
# ____________________________________
# - DATAN1 & DATAN3 are superposed (exact same variation & correlation with all other variables)
# We will only consider DATAN1 in our interpretation.
# - DATAN1 & DATAN2 are almost identical in terms of variation & correlation.
#
# - DATAN2 has a slighlty larger correlation for CODENT_enc.
#
# Negatively correlated with DATAN1 :
# - very lightly : Qualit_enc
#
# Positively correlated with DATAN1 :
# - Highly : DATCON, DEBESS,-- DATENT,  DATSOR
# - Highly- : SEN_DUR_1_int, DATFIN
# ____________________________________
# Negatively correlated with DTCY02 :
# - Highly : SEN_DUR_1_int (-0.5)
# - Lightly : SEN_DUR_2_int
#
# Positively correlated with DTCY02 :
# - Medium : DTCY02
# - Medium- : DATAN4
# - lighter- : CODSOR_enc, CODENT_enc
#
# _______________________________________
# Negatively correlated with PHYSOR :
# - High : ESS_DUR_int
# - Medium : FINESS, CODSOR_enc
# _______________________________________
# Negatively correlated with DATENT :
# - Medium : SEN_GRP_DUR_int
# - Very lightly : Qualit_enc (Minority class entries)
#
# Positively correlated with DATENT
# - NUDOSS : Means that more Entry Dates in recent years correspond to higher values for NUDOSS (which totally natural) - Discard, irrelevant
# - Highly+ : DATCON (contract)
# - DATAN1, DATAN2, DATAN3
# - Medium+ : DEBESS, DATFIN
# - Medium : SEN_DUR_1_int

# %% [markdown]
# **==> The Date features that will be kept are Date Features that strongly correlate with other numerical values indirectly (Numerical features not linked to the date through a linear function)**
#
# NOTE :
# - 'CONT_GRP_DUR' = 'DATFIN'- **DATCON**
# - **ESS_DUR** = FINESS - DEBESS
# - 'SEN_DUR_2' = **DTCY01** - DTCY02
# - 'SEN_DUR_1' = DATCON - DTCY01
# - 'SEN_GRP_DUR' = **DATSOR**-'DATENT'

# %% [markdown]
# **TO KEEP = DATCON, DTCY01, DATSOR, ESS_DUR, CONT_GRP_DUR, SEN_DUR_2, SEN_DUR_1, SEN_GRP_DUR**

# %% [markdown]
# ### ii. Scree Plot

# %% [markdown]
# #### ==> 6 Variables are enough to represent 80% of the data

# %% [markdown]
# ### iii. Correlation circle

# %% [markdown]
# ![image.png](attachment:6560794d-8389-4456-a822-18a9f64bdff7.png)

# %% [markdown]
# - DURANN , DURMOI & DURJOU are superposed.
# - CODSOR_enc is highly negatively correlated with SEN_DUR_1_int (Seniority in company -1)
# - DURANN , DURMOI ; DURJOU && QUALIT_enc are strongly negatively correlated.  : Mr 1 -- Mrs 2 -- Miss 3
#
# - The remaining values[CODENT_enc, CODSOR_enc,SEN_DUR_2_int,CONT_GRP_DUR_int,SEN_GRP_DUR_int,ESS_DUR_int] are practically superposed
#
# **TO KEEP = 'DURANN', 'ReEntry', 'CODSOR_enc', 'CODENT_enc', 'QUALIT_enc', 'SEN_DUR_2_int','CONT_GRP_DUR_int', 'SEN_GRP_DUR_int', 'SEN_DUR_1_int'**

# %% [markdown]
# ## b. Combination of categorical & numerical key Features for the Misclassification Fraud :

# %% [markdown]
# ### - We plot Seniority in the Group relative to the same Employee (MATCLE), and visualized how Job Titles relate to seniority :

# %% [markdown]
# ![image.png](attachment:f0040de4-3274-41b2-b0fa-0a3059283040.png)

# %% [markdown]
# The plots are always divided into 2 main rows :
# - 1st : ranges from 0 to 2000 (or 5000) days : represents employees who left the group ( possibly rerecruited in the future)
# - 2nd : ranges from 10000 to 12000 (or 17500) days : represents employees who are currently in the group (that's explained by huge number of years surpassing or nearing Retraite age (17500/365 = 48 years))
#
# On the x axis : there are phases of employee titles :
# - Employee, E1, E2, E3, E4 in the same x range, followed by :
# - Supervisor, Assimilated Executive titles in the same x range
# and so on, which most likely correspond to different recruitement phases (Junior roles, senior roles etc.)
#
# On the Y axis :
# For the same row, we can see that there are carrier upgrades for the same employee (MATCLE) from Employee to supervisor ; from supervisor to Executive.
# ___________________________________________________________________________
#
# In the upper row (currently in employees, in the downard part that corresponds mostly to Rercruits or transfer employees) we can find Higher executive roles, despite it not belonging to a recruitement phase of the same type --> which means that the job title was in accordance with the employee's seniority in the group and past Experience.
# ____________________________________________________

# %% [markdown]
# A plot to validate our hypothesis shows :
# ![image.png](attachment:8bbf48dd-f29f-456b-b334-33192c084852.png)

# %% [markdown]
# Those who are currently in, are either Rerecruits to the same company in the group, or transfer employees from other compnaies in the group.

# %% [markdown]
# Thos graph, showing Entry Category, validates our 2nd hypothesis again :
# ![image.png](attachment:b352f5e4-f186-4555-91c2-a7264503feb9.png)

# %% [markdown]
# These are the full plots for the entire dataset (the previous ones were selection on the data for visulaization clarity) :

# %% [markdown]
# ![image.png](attachment:54b2caf2-c2ac-4f16-a36d-a4602998fa50.png)

# %% [markdown]
# ![image.png](attachment:e25c232c-563e-45c4-9442-83055729bee1.png)

# %% [markdown]
# ### - What does this mean concerning the Misclassification Fraud data generation ?
# Typical sane scenarios resemble :
# - Employee : { CODSOR = curently in , CODENT = Rerecruited , Seniority_in_Group in [11000-13500] }
# - Employee : { CODSOR = curently in , CODENT = Mutation , Seniority_in_Group in [10000-12500] }
# - Employee : { CODSOR = curently in , CODENT = New recruit , Seniority_in_Group in [12000-17500] }
#
# We will only consider scenarios of employees who are still in the company.

# %% [markdown]
# Based on the same reasoning, we plot relative to Contract date (instead of seniority) :

# %% [markdown]
# ![image.png](attachment:1148f658-730c-4ae9-9d64-b9ffd28476a1.png)

# %% [markdown]
# ### - Misclassification Fraud data generation :
# Typical sane scenarios resemble :
# - Employee : { CODSOR = curently in , CODENT = Rerecruited , CONTRACT_Duration_Group in [12000-18000] }
# - Employee : { CODSOR = curently in , CODENT = Mutation , CONTRACT_Duration_Group in [10000-14000] }
# - Employee : { CODSOR = curently in , CODENT = New recruit , CONTRACT_Duration_Group in [11000-17000] }
#
# We will only consider scenarios of employees who are still in the company.

# %% [markdown]
# # 3. Ghost Worker Fraud

# %% [markdown]
# ## a. MCA

# %% [markdown]
# ### i. Axis Contribution

# %% [markdown]
# ______________________________________________________________________________________
# #### **Interpretation( with seniority duration)**
# - col4_Mutation & col7_ORGANI have maximum contribution to the 1st Dimension
# - col4_Currently IN has maximum contribution to the 2nd Dimension
#
# #### **Interpretation( without seniority duration)**
# - LEAVE REASON : col4_Mutation & col7_ORGANI have maximum contribution to the 1st Dimension
# - col2_F IN has maximum contribution to the 2nd Dimension
#
# ______________________________________________________________________________________

# %% [markdown]
# ### ii. Factor Maps

# %% [markdown]
# ![image.png](attachment:16cfb51e-b21d-4c19-8f1f-98babfc5ee60.png)

# %% [markdown]
# ![image.png](attachment:dc6290ca-d438-4953-9a05-9f32f764bdec.png)

# %% [markdown]
# ![image.png](attachment:76da0b47-9e4f-46cc-af1c-b3e7b737f91e.png)

# %% [markdown]
# ![image.png](attachment:9778c0e4-230e-4740-9dde-d9bed7f6285a.png)

# %% [markdown]
# ![image.png](attachment:d5f08268-e9a7-4b12-9ee6-caaa45eaa3f1.png)

# %% [markdown]
# ![image.png](attachment:7f25aaaa-d809-4856-a94d-16ced6b16c9d.png)

# %% [markdown]
# ![image.png](attachment:1f7493a0-495b-490a-a6d1-411ed8fbb38f.png)

# %% [markdown]
# - **Document type** : 42 & 44 are superposed
# - **Document type** 42 , 44 & 45 score highest on **Deposit platform** : **F**
# ___
# - **Transfer company**: TMG, ATX, ITI, IMI, SMS, ITM are closest to eachother, and score highest on the **'Mutation axis' : Leave Reason**
# - **Transfer company**: col8 : **TWW** scores highest on the 'Mutation axis', and is closest to **Mutation & Internal Organisation reasons for transfer**
# ___
# - **Current company** : TMG , **Absence Code** : CSS, **Leave_Category** : CurrentlyIN are closest to eachother
# ____
# - No_Deposit , **Entry_Reason : Mutation** , **Absence Code** :  CPN , STANDA , **Current company** : IIS , **Document type**: DOC20  & **Entry Category** : **ReRecruited** are closest to eachother
#
# ____
# - Mr & DOC33 are closest to eachother
# - CurrentlyIn , Scan_Validated ,  **Current company** : SBS , **Absence Code** : MAT
# - **Absence Code** : CSO , DOC32,  **Current company** : EXM SMS ATX
# - **Absence Code** : MAB & **Current company** : SBS
# ____
# Concerning Leave_Reason :
# - **Leave_Reason : RPU** contributes most to the Mutation axis
# - **ABS : Unjustified Absence** contributes most to the Mutation axis
# - **DESIST** is farthest from the absence reasons cluster.
# - ---
# Most absence reasons are very close to eachother, if we were to make associations :
# - CNTFM, MOFNO, FPEF, RAIPR, DEPET
# - FINCTR, MALGR, ABN,
# - MOFOF, REMUN, ABF, PBMAN, autre, DEM

# %% [markdown]
# ## b. PCA

# %% [markdown]
# ### i. Correlation Matrix

# %% [markdown]
# ![image.png](attachment:2650f16e-8666-4711-b1c9-d2a0c1c8ffca.png)

# %% [markdown]
# CODSOR_enc (which is higher for dominant CODSOR values) is negatively correlated with  :
# - Very highly : DATSOR
# - Very highly : SEN_GRP_DUR
# _________
# - DATSOR & SEN_GRP_DUR : Highly positively correlated
#
# - DATDEB,DATFN & PHYSOR : HIGHLY POSITIVE
#
# __________
#
# CODSOR_enc = {1 : CURRENTLY IN ; 2 :  left ; 3 : mutation}

# %% [markdown]
# ### ii. Scree Plot

# %% [markdown]
# ==> 4 Variables are enough to represent 80% of the data

# %% [markdown]
# ### iii. Correlation Circle

# %% [markdown]
# ![image.png](attachment:7a6516b9-53cf-4ca3-be76-71c191f78631.png)

# %% [markdown]
# The correlations are not relevant enough to be interpreted.
