# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import seaborn as sns
from scipy import stats

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA

from itertools import combinations
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
import statsmodels.api as sm
import statsmodels.tsa.api as smt
pd.options.display.float_format = '{:.2f}'.format

# %%
df_pay_sums = pd.read_csv(r"C:\Users\LENOVO\Desktop\Payroll_PFE\Payroll Analysis & Forecasting\1. Data\df_analysis_contr_overtime_bonus.csv")
df_pay_sums['PERPAI'] = pd.to_datetime(df_pay_sums['PERPAI'], format='%Y-%m-%d')

# %%
def plot_many(List_names):
    l_p=[]
    for col in List_names :
        l_p.append(pd.Series(list(df_PAT[col]), index=list(df_PAT['PERPAI'])))

    plt.subplots(1, 1, figsize=(25, 10))
    for i in range(len(l_p)) : 
       plt.plot(l_p[i],label=List_names[i])
    
    plt.legend()
    plt.show()

# %% [markdown]
# ## Regular plots

# %%
# PAT
plt.subplots(1, 1, figsize=(20, 6))
data = pd.Series(list(df_pay_sums['Bonuses_sum']), index=list(df_pay_sums['PERPAI']))

plt.plot(data, color='orange')
#plt.plot(data1)
plt.title('Number of ')
# Out:
# Text(0.5, 1.0, 'Number of ')

# %%
# PAT
plt.subplots(1, 1, figsize=(20, 6))
data = pd.Series(list(df_pay_sums['Overtime_sum']), index=list(df_pay_sums['PERPAI']))

plt.plot(data, color='blue')
#plt.plot(data1)
plt.title('Number of ')
# Out:
# Text(0.5, 1.0, 'Number of ')

# %%
# PAT
plt.subplots(1, 1, figsize=(20, 6))
data = pd.Series(list(df_pay_sums['Contributions_sum']), index=list(df_pay_sums['PERPAI']))

plt.plot(data, color='green')
#plt.plot(data1)
plt.title('Number of ')
# Out:
# Text(0.5, 1.0, 'Number of ')

# %%
# PAT
plt.subplots(1, 1, figsize=(20, 6))
data = pd.Series(list(df_pay_sums['Indemnities_sum']), index=list(df_pay_sums['PERPAI']))

plt.plot(data, color='y')
#plt.plot(data1)
plt.title('variation')
# Out:
# Text(0.5, 1.0, 'Number of ')

# %%
# PAT
plt.subplots(1, 1, figsize=(20, 6))
data5 = pd.Series(list(df_pay_sums['Conge_sum']), index=list(df_pay_sums['PERPAI']))

plt.plot(data5, color='purple')
#plt.plot(data1)
plt.title('Leave Days variation ')
# Out:
# Text(0.5, 1.0, 'Leave Days variation ')

# %%
# PAT
plt.subplots(1, 1, figsize=(20, 6))
data1 = pd.Series(list(df_pay_sums['Overtime_sum']), index=list(df_pay_sums['PERPAI']))
data2 = pd.Series(list(df_pay_sums['Contributions_sum']), index=list(df_pay_sums['PERPAI']))
data3 = pd.Series(list(df_pay_sums['Indemnities_sum']), index=list(df_pay_sums['PERPAI']))
data4 = pd.Series(list(df_pay_sums['Bonuses_sum']), index=list(df_pay_sums['PERPAI']))
data5 = pd.Series(list(df_pay_sums['Conge_sum']), index=list(df_pay_sums['PERPAI']))

plt.plot(data1,label='Overtime_sum')
plt.plot(data2,label='Contributions_sum')
plt.plot(data3,label='Compensation_sum') 
# plt.plot(data4,label='Bonuses_sum')
plt.plot(data5,label='Conge_sum') 
plt.legend()
# plt.savefig("variation of company charges.png")
plt.savefig("variation of company charges_0.png")
plt.title('variation of company charges')
# Out:
# Text(0.5, 1.0, 'variation of company charges')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Perform seasonal decomposition
result = seasonal_decompose(data2, model='additive', period=12)  # Assuming daily seasonality for hourly data

# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(15, 12))

# Plot observed data
axes[0].plot(result.observed,color='orange')
axes[0].set_title('Observed - Contributions')

# Plot trend data
axes[1].plot(result.trend,color='orange')
axes[1].set_title('Trend - Contributions')

# Plot seasonal data
axes[2].plot(result.seasonal,color='orange')
axes[2].set_title('Seasonal - Contributions')

# # Plot residual data
# axes[3].plot(result.resid,color='orange')
# axes[3].set_title('Residual - Contributions')

# Adjust layout and show plot
plt.tight_layout()

fig.savefig("Contributions_TS.png")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Perform seasonal decomposition
result = seasonal_decompose(data1, model='additive', period=12)  # Assuming daily seasonality for hourly data

# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(15, 12))

# Plot observed data
axes[0].plot(result.observed,color='b')
axes[0].set_title('Observed - Overtime')

# Plot trend data
axes[1].plot(result.trend,color='b')
axes[1].set_title('Trend - Overtime')

# Plot seasonal data
axes[2].plot(result.seasonal,color='b')
axes[2].set_title('Seasonal - Overtime')

# # Plot residual data
# axes[3].plot(result.resid,color='b')
# axes[3].set_title('Residual - Overtime')

# Adjust layout and show plot
plt.tight_layout()

fig.savefig("Overtime_TS.png")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Perform seasonal decomposition
result = seasonal_decompose(data3, model='additive', period=12)  # Assuming daily seasonality for hourly data

# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(15, 12))

# Plot observed data
axes[0].plot(result.observed,color='green')
axes[0].set_title('Observed - Indemnities')

# Plot trend data
axes[1].plot(result.trend,color='green')
axes[1].set_title('Trend - Indemnities')

# Plot seasonal data
axes[2].plot(result.seasonal,color='green')
axes[2].set_title('Seasonal - Indemnities')

# # Plot residual data
# axes[3].plot(result.resid,color='green')
# axes[3].set_title('Residual - Indemnities')

# Adjust layout and show plot
plt.tight_layout()

fig.savefig("Indemnities_TS.png")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Perform seasonal decomposition
result = seasonal_decompose(data4, model='additive', period=12)  # Assuming daily seasonality for hourly data

# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(15, 12))

# Plot observed data
axes[0].plot(result.observed,color='red')
axes[0].set_title('Observed - Bonuses')

# Plot trend data
axes[1].plot(result.trend,color='red')
axes[1].set_title('Trend - BonusesBonuses')

# Plot seasonal data
axes[2].plot(result.seasonal,color='red')
axes[2].set_title('Seasonal - Bonuses')

# # Plot residual data
# axes[3].plot(result.resid,color='red')
# axes[3].set_title('Residual - Bonuses')

# Adjust layout and show plot
plt.tight_layout()

fig.savefig("Bonuses_TS.png")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Perform seasonal decomposition
result = seasonal_decompose(data5, model='additive', period=12)  # Assuming daily seasonality for hourly data

# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(15, 12))

# Plot observed data
axes[0].plot(result.observed,color='purple')
axes[0].set_title('Observed - Bonuses')

# Plot trend data
axes[1].plot(result.trend,color='purple')
axes[1].set_title('Trend - conge')

# Plot seasonal data
axes[2].plot(result.seasonal,color='purple')
axes[2].set_title('Seasonal - conge')

# # Plot residual data
# axes[3].plot(result.resid,color='red')
# axes[3].set_title('Residual - Bonuses')

# Adjust layout and show plot
plt.tight_layout()

fig.savefig("conge_TS.png")

plt.show()

# %%
def test_stationarity(timeseries):
    #Determing rolling statistics
    MA = timeseries.rolling(window = 12).mean()
    MSTD = timeseries.rolling(window = 12).std()

    #Plot rolling statistics:
    plt.figure(figsize=(15,5))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(MA, color='red', label='Rolling Mean')
    std = plt.plot(MSTD, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(data1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -3.03
# p-value                        0.03
# #Lags Used                     1.00
# Number of Observations Used   22.00
# Critical Value (1%)           -3.77
# Critical Value (5%)           -3.01
# Critical Value (10%)          -2.64
# dtype: float64

# %%
test_stationarity(data2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.33
# p-value                        0.00
# #Lags Used                     0.00
# Number of Observations Used   23.00
# Critical Value (1%)           -3.75
# Critical Value (5%)           -3.00
# Critical Value (10%)          -2.64
# dtype: float64

# %%
test_stationarity(data3)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -4.31
# p-value                        0.00
# #Lags Used                     0.00
# Number of Observations Used   23.00
# Critical Value (1%)           -3.75
# Critical Value (5%)           -3.00
# Critical Value (10%)          -2.64
# dtype: float64

# %%
test_stationarity(data4)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.73
# p-value                        0.00
# #Lags Used                     0.00
# Number of Observations Used   23.00
# Critical Value (1%)           -3.75
# Critical Value (5%)           -3.00
# Critical Value (10%)          -2.64
# dtype: float64
